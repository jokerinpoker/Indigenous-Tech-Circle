# %%
import pandas as pd
import time

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Scrape more Indigenous Businesses (CCIB)

# %%
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.edge.service import Service
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException, TimeoutException

def init_service(headless=False):
    # Initialize
    driver_path = '/Users/zhangliyao/Downloads/chromedriver'
    chrome_options = webdriver.ChromeOptions()
    chrome_options.add_argument('--enable-automation')
    if headless:
        chrome_options.add_argument('--headless')
    
    driver = webdriver.Chrome(service=Service(executable_path=driver_path), options=chrome_options)
    driver.implicitly_wait(10)
    driver.get('https://www.ccab.com/main/ccab_member/?qcompanyname&qccabindustry&qccabprogram&qccabterritory&qccabmembershiptype&qccabindex&s')
    time.sleep(2)
    driver.fullscreen_window()
    
    return driver

driver = init_service()
num_total = 0
has_next = True
#limit = 50
company_names = []
while has_next:
    company_list = driver.find_elements(By.CLASS_NAME, 'article')
    num_total += len(company_list)
    for element in company_list:
        company_names.append(element.text)
    try:
        driver.find_element(By.CLASS_NAME, 'next.page-numbers').click()
        driver.fullscreen_window()
        time.sleep(1)
    except:
        has_next = False
        
print("companies found:", num_total)

df = pd.DataFrame(company_names, columns=['Company Name'])
df.to_excel('CCIB_members.xlsx', index=False)

# %%
import chardet

with open("../data/raw/indigenous_business_directory.csv", "rb") as file:
    raw_data = file.read()
    result = chardet.detect(raw_data)
    print(result)
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %% [markdown]
# ## Data Loading

# %%
ind_business = pd.read_csv("../data/raw/indigenous_business_directory.csv", encoding="ISO-8859-1")
CCIB = pd.read_excel("../data/raw/CCIB_members.xlsx")

fed_contract = pd.read_csv("../data/raw/search_contracts_2023.csv", low_memory=False,
    usecols=['procurement_id','vendor_name','contract_date','economic_object_code','description_eng',
             'contract_value','comments_eng','additional_comments_eng','commodity_type_en',
             'solicitation_procedure_en','indigenous_business_excluding_psib_en','owner_org_en',
             'indigenous_business_en','award_criteria_en'])
print(len(fed_contract))
# Out:
# 81153

# %% [markdown]
# ## Data Cleaning

# %%
# Sanity check

## contract value
fed_contract = fed_contract[fed_contract['contract_value'] >= 10000]

## unique id
fed_contract = fed_contract.drop_duplicates(subset='procurement_id', keep='first')

## not null description
fed_contract = fed_contract[fed_contract['description_eng'].notnull()]

print(len(fed_contract))
# Out:
# 70307

# %%
# Identify Indigenous Businesses

fed_contract['clean_vendor_name'] = fed_contract['vendor_name'].str.lower()
ind_business['Company Operating Name'] = ind_business['Company Operating Name'].str.lower()
ind_business['Company Legal Name'] = ind_business['Company Legal Name'].str.lower()
CCIB['Company Name'] = CCIB['Company Name'].str.lower()

# Match vendor with indigenous business directory
df_merge1 = pd.merge(fed_contract, ind_business, left_on='clean_vendor_name', right_on='Company Operating Name')
df_merge2 = pd.merge(fed_contract, ind_business, left_on='clean_vendor_name', right_on='Company Legal Name')
df_merge3 = pd.merge(fed_contract, CCIB, left_on='clean_vendor_name', right_on='Company Name')

print(len(df_merge1), len(df_merge2), len(df_merge3))

# Concatenate the two merge results
df_combined = pd.concat([df_merge1, df_merge2, df_merge3])

# Drop duplicate rows (e.g., based on 'vendor_name' to avoid double counting the same vendor)
df_final = df_combined.drop_duplicates(subset='procurement_id')
print(len(df_final))

# Mark contracts that match these names as 'IB'
fed_contract['is_IB'] = fed_contract['clean_vendor_name'].apply(lambda name: True if name in set(df_final['clean_vendor_name']) else False)
fed_contract['is_IB'].describe()
# Out:
# 1356 1478 2046
# 3294
# count     70307
# unique        2
# top       False
# freq      67013
# Name: is_IB, dtype: object

# %%
# Mark PSIB status

def mark_PSIB(row):
    if row['indigenous_business_en'] == '2. Mandatory Set-Aside':
        return 'Mandatory Set-Aside'
    elif row['indigenous_business_en'] == '3. Voluntary Set-Aside':
        return 'Voluntary Set-Aside'
    elif row['indigenous_business_excluding_psib_en'] == 'Yes':
        return 'PSAB'
    return 'None'

fed_contract['PSIB'] = fed_contract.apply(mark_PSIB, axis=1)
fed_contract['PSIB'].value_counts()
# Out:
# PSIB
# None                   67204
# PSAB                    1996
# Voluntary Set-Aside      802
# Mandatory Set-Aside      305
# Name: count, dtype: int64

# %%
# Categorize industry, focus on tech
tech_dict = {
    '231':'Data Communication Services',
    '362':'Data & Database Access Services',
    '430':'Scientific Services',
    '431':'Scientific Consultants',
    '473':'Information Technology and Telecommunications Consultants',
    '492':'Research Contracts',
    '520':'Renewal of Annual Licenses/Maintenance for Software',
    '582':'License/Maintenance fees for Client Software',
    '583':'License/Maintenance fees for Application Software',
    '584':'License/Maintenance fees for Operating System and Utility Software',
    '585':'License/Maintenance fees for Networking Software',
    '587':'Rental of Computer Equipment related to Production and Operations',
    '588':'Rental of Computer Equipment related to Distributed Computing Environment',
    '590':'License/Maintenance fees for Image/Video Communications Software',
    '660':'Measuring, Controlling, Laboratory, Medical and Optical Instruments, Apparatus and Accessories',
    '672':'Computer Equipment - Servers',
    '812':'Computer Services',
    '920':'Acquisition of Client Software',
    '1243':'Measuring, Controlling, Laboratory, Medical and Optical Equipment and Parts',
    '1282':'Computer Equipment related to Production and Operations',
    '1283':'Computer Equipment related to Distributed Computing Environment',
    '1284':'Client Software related to Distributed Computing',
    '1285':'Application Software, Application Development and Delivery Software',
    '1286':'Operating System and Utility Software',
    '1287':'Networking Software',
    '1291':'Image/Video Communications Software',
    '1364':'Laboratories',
}

fed_contract['is_Tech'] = fed_contract['economic_object_code'].apply(lambda code: True if code in tech_dict.keys() else False)
fed_contract['is_Tech'].describe()
#services = fed_contract[fed_contract['commodity_type_en']=='Service']
#services['description_eng'].value_counts()
#
#fed_contract[fed_contract['description_eng'].str.contains('computer')].economic_object_code.value_counts()
#fed_contract[fed_contract['economic_object_code']=='640'].description_eng.value_counts()
# Out:
# count     70307
# unique        2
# top       False
# freq      55902
# Name: is_Tech, dtype: object

# %%
# drop unused columns
fed_contract.drop(['comments_eng','additional_comments_eng','indigenous_business_excluding_psib_en',
                   'indigenous_business_en','clean_vendor_name'], axis=1, inplace=True)

# %%
fed_contract.head()
# Out:
#   procurement_id                            vendor_name         contract_date  \
# 0     3000758543                          GENOME QUEBEC  2023-01-19T00:00:00Z
# 1     3000762275                  HARTLAND AGROMART LTD  2023-03-14T00:00:00Z
# 2     3000759579  GLACIER FARMMEDIA LIMITED PARTNERSHIP  2023-02-02T00:00:00Z
# 3     3000759047         SDL INTERNATIONAL (CANADA) INC  2023-01-26T00:00:00Z
# 4     3000758553                          GENOME QUEBEC  2023-01-19T00:00:00Z
#
#   economic_object_code                                    description_eng  \
# 0                  430                                Scientific services
# 1                 1121               Salt, sulphur, ores, earth and stone
# 2                  361  Electronic subscriptions and electronic public...
# 3                  583  License/Maintenance fees for application softw...
# 4                  430                                Scientific services
#
#    contract_value commodity_type_en   solicitation_procedure_en  \
# 0        40137.60           Service  Competitive – Open Bidding
# 1        13000.00              Good   Competitive – Traditional
# 2        11566.80           Service             Non-Competitive
# 3        12954.32           Service             Non-Competitive
# 4        26758.40           Service  Competitive – Open Bidding
#
#                        owner_org_en award_criteria_en  is_IB  PSIB  is_Tech
# 0  Agriculture and Agri-Food Canada    Not applicable  False  None     True
# 1  Agriculture and Agri-Food Canada      Lowest Price  False  None    False
# 2  Agriculture and Agri-Food Canada    Not applicable  False  None    False
# 3  Agriculture and Agri-Food Canada    Not applicable  False  None     True
# 4  Agriculture and Agri-Food Canada    Not applicable  False  None     True

# %%
#fed_contract = pd.read_csv('../data/processed/clean2023.csv')

# %%
fed_contract['award_criteria_en'] = fed_contract['award_criteria_en'].replace('-', 'Not applicable')

# %%
fed_contract['PSIB'] = fed_contract['PSIB'].fillna('None')

# %%
fed_contract.to_csv('../data/processed/clean2023.csv', index=False)

# %% [markdown]
# ## Jun's Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Read files
df1 = pd.read_excel('../data/raw/CCIB_members.xlsx')
df2 = pd.read_csv("../data/raw/search_contracts_2023.csv", low_memory=False)
df3 = pd.read_csv("../data/raw/indigenous_business_directory.csv", encoding="ISO-8859-1")

# Step 2: Mark PSIB status
df2['PSIB_Status'] = df2.apply(
    lambda row: 'PSIB' if (
        row['indigenous_business_en'] in ['2. Mandatory Set-Aside', '3. Voluntary Set-Aside'] 
        or row['indigenous_business_excluding_psib_en'] == 'Yes'
    ) else 'NON-PSIB',
    axis=1
)

# Step 3: PSIB vs NON-PSIB distribution (Pie chart)
# Calculate the count of contracts for PSIB and NON-PSIB
psib_counts = df2['PSIB_Status'].value_counts()

# Calculate the total contract value for PSIB and NON-PSIB
psib_contract_value = df2.groupby('PSIB_Status')['contract_value'].sum()

# Create subplots for both pie charts
fig, axs = plt.subplots(1, 2, figsize=(12, 6))  # 1 row, 2 columns

# Plot 1: Contract Count Distribution (Pie chart)
psib_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, ax=axs[0])
axs[0].set_title('PSIB vs NON-PSIB Contract Count Distribution')
axs[0].set_ylabel('')  # Remove the y-label for the pie chart

# Plot 2: Contract Value Distribution (Pie chart)
psib_contract_value.plot(kind='pie', autopct='%1.1f%%', startangle=90, ax=axs[1])
axs[1].set_title('PSIB vs NON-PSIB Contract Value Distribution')
axs[1].set_ylabel('')  # Remove the y-label for the pie chart

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plots
plt.show()

# Step 4: Mark IB Status
# Helper function to clean company names (ignore case and remove extra spaces)
def clean_name(name):
    if pd.isna(name):
        return ""
    return name.strip().lower()

# Clean company names in relevant columns
df1['clean_company_name'] = df1['Company Name'].apply(clean_name)  # CCIB_members.csv
df2['clean_vendor_name'] = df2['vendor_name'].apply(clean_name)    # contracts-2023.csv
df3['clean_legal_name'] = df3['Company Legal Name'].apply(clean_name)  # indigenous_business_directory.csv

# Create a set of all clean company names from CCIB and Indigenous directories (only using Company Name and Legal Name)
ib_company_names = set(df1['clean_company_name']).union(set(df3['clean_legal_name']))

# Mark contracts that match these names as 'IB'
df2['IB_Status'] = df2['clean_vendor_name'].apply(lambda name: 'IB' if name in ib_company_names else 'NON-IB')

# Step 5: Count the number of IB and NON-IB contracts
ib_counts = df2['IB_Status'].value_counts()

# Print the result
print("IB and NON-IB counts in the main table:")
print(ib_counts)

# Step 5: PSIB vs IB detailed distribution under PSIB
# Calculate the count of IB and NON-IB contracts under PSIB
psib_ib_counts = df2.groupby(['PSIB_Status', 'IB_Status']).size().unstack()
psib_ib = psib_ib_counts.loc['PSIB']

#  Calculate the total contract value for IB and NON-IB under PSIB
psib_ib_value = df2[df2['PSIB_Status'] == 'PSIB'].groupby('IB_Status')['contract_value'].sum()

#  Create subplots for both pie charts
fig, axs = plt.subplots(1, 2, figsize=(12, 6))  # 1 row, 2 columns

# Plot 1: Contract Count Distribution (Pie chart for IB vs NON-IB under PSIB)
psib_ib.plot(kind='pie', autopct='%1.1f%%', startangle=90, ax=axs[0])
axs[0].set_title('IB vs NON-IB Contract Count under PSIB')
axs[0].set_ylabel('')  # Remove the y-label for the pie chart

# Plot 2: Contract Value Distribution (Pie chart for IB vs NON-IB under PSIB)
psib_ib_value.plot(kind='pie', autopct='%1.1f%%', startangle=90, ax=axs[1])
axs[1].set_title('IB vs NON-IB Contract Value under PSIB')
axs[1].set_ylabel('')  # Remove the y-label for the pie chart

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plots
plt.show()


# Step 6: Filter out contracts with contract_value less than 1000
df2_cleaned = df2[df2['contract_value'] >= 1000]

# Define a keyword dictionary for contract classification
categories_keywords = {
    'Technology': ['software', 'information technology', 'hardware', 'network', 'AI', 'data analysis'],
    'Goods': ['office supplies', 'furniture', 'equipment', 'stationery', 'food'],
    'Construction': ['construction', 'building', 'road', 'bridge', 'infrastructure'],
    'Services': ['training', 'consulting', 'audit', 'repair', 'advertising', 'cleaning'],
}

# Step 7: Classify contracts based on description_eng
def classify_description(description):
    description = str(description).lower()  
    for category, keywords in categories_keywords.items():
        for keyword in keywords:
            if keyword.lower() in description:
                return category
    return 'Other'  

df2_cleaned['Category'] = df2_cleaned['description_eng'].apply(classify_description)

# View the classification result
print(df2_cleaned[['description_eng', 'Category']].head())

# Step 8: Contract category distribution (Bar chart)
category_counts = df2_cleaned['Category'].value_counts()
category_counts.plot(kind='bar')
plt.title('Contract Categories Distribution')
plt.xlabel('Category')
plt.ylabel('Number of Contracts')
plt.show()

# Step 9: Plot contract value proportion for PSIB and NON-PSIB
def plot_contract_value_proportion(psib_status):
    grouped = df2_cleaned[df2_cleaned['PSIB_Status'] == psib_status].groupby(['IB_Status', 'Category'])['contract_value'].sum().unstack()
    grouped.plot(kind='bar', stacked=True)
    plt.title(f'Contract Value Proportion for {psib_status} - IB vs NON-IB')
    plt.xlabel('IB Status')
    plt.ylabel('Total Contract Value')
    plt.show()

# Plot for PSIB contracts
plot_contract_value_proportion('PSIB')

# Plot for NON-PSIB contracts
plot_contract_value_proportion('NON-PSIB')

# Step 10: Top 20 vendors in Technology under PSIB and NON-IB
# 1: Filter out all contracts that are in PSIB, Technology, and NON-IB
filtered_contracts = df2_cleaned[ 
    (df2_cleaned['PSIB_Status'] == 'PSIB') & 
    (df2_cleaned['IB_Status'] == 'NON-IB') & 
    (df2_cleaned['Category'] == 'Technology')
]

# 2: Group by 'vendor_name' and sum the contract values for each vendor
aggregated_contracts = filtered_contracts.groupby('vendor_name')['contract_value'].sum().reset_index()

# Step 3: Find the top 20 vendors by contract value
top_technology_vendors = aggregated_contracts.nlargest(20, 'contract_value')

# Step 4: Display the top 20 vendors
print(top_technology_vendors[['vendor_name', 'contract_value']])

# Step 5: Plot the top 20 vendors and their contract values
top_technology_vendors.plot(kind='barh', x='vendor_name', y='contract_value', legend=False)
plt.title('Top 20 NON-IB Vendors in Technology under PSIB')
plt.xlabel('Contract Value')
plt.ylabel('Vendor Name')
plt.tight_layout()
plt.show()


# Step 11: Divide by contract value ranges
bins = [0, 10000, 25000, 100000, 1000000, 5000000, float('inf')]
labels = ['Less than $10,000', '$10,000 - $25,000', '$25,000 - $100,000', 
          '$100,000 - $1,000,000', '$1,000,000 - $5,000,000', 'More than $5,000,000']

df2['Contract Value Range'] = pd.cut(df2['contract_value'], bins=bins, labels=labels, right=False)

# Check the result
print(df2[['contract_value', 'Contract Value Range']].head())

# Step 12: Contract value distribution by range (Bar chart)
value_range_counts = df2['Contract Value Range'].value_counts(sort=False)
value_range_counts.plot(kind='bar', color='skyblue')
plt.title('Contract Value Distribution by Range')
plt.xlabel('Contract Value Range')
plt.ylabel('Number of Contracts')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# IB and NON-IB counts in the main table:
# IB_Status
# NON-IB    77503
# IB         3660
# Name: count, dtype: int64
#                                      description_eng    Category
# 0                                Scientific services       Other
# 1               Salt, sulphur, ores, earth and stone       Other
# 2  Electronic subscriptions and electronic public...       Other
# 3  License/Maintenance fees for application softw...  Technology
# 4                                Scientific services       Other
# /var/folders/1_/rzq84md92bnghbv760b2dk_40000gn/T/ipykernel_44124/3167631266.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_cleaned['Category'] = df2_cleaned['description_eng'].apply(classify_description)
#                                            vendor_name  contract_value
# 7                               ADIRONDACK INFORMATION     87236869.00
# 12                          ADRM TECHNOLOGY CONSULTING     54402539.69
# 75                              MAKWA RESOURCING INC.,     25742711.00
# 121                                     TELESAT CANADA     19299906.00
# 91                 ONAKI CREATION S.E.N.C., IBISKA TEL     17191811.16
# 18                      ADVANCED CHIPPEWA TECHNOLOGIES     16042574.86
# 47                                   CLICK SPIRIT INC.     15814364.00
# 108  TATO RECRUITING AND S.I. SYSTEMS ULC, IN JOINT...     15375182.00
# 13                 ADRM TECHNOLOGY CONSULTING GROUP CO     14760824.30
# 50                              DALIAN ENTERPRISES INC     13250000.00
# 9          ADRM TEC AND RANDSTAD INTERIM INC. IN A CJV     11531386.00
# 49   DALIAN ENTERPRISES AND CORADIX TECHNOLOGY CONS...      8227076.00
# 76   MAKWA RESOURCING INC., TPG TECHNOLOGY CONSULTI...      8197530.00
# 109                                TATO RECRUITING INC      7500000.00
# 54                                      DONNA CONA INC      7350862.15
# 96      Onaki Créations S.E.N.C, IBISKA  Telecom Inc.,      6532711.00
# 19                 ADVANCED CHIPPEWA TECHNOLOGIES INC.      6373997.64
# 68                                            IPSS INC      6289426.67
# 71                                MAKWA RESOURCING INC      4369641.32
# 115  TATO RECRUITING INC. AND S.I. SYSTEMS ULC IN J...      3955000.00
# /var/folders/1_/rzq84md92bnghbv760b2dk_40000gn/T/ipykernel_44124/3167631266.py:167: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
#    contract_value Contract Value Range
# 0        40137.60   $25,000 - $100,000
# 1        13000.00    $10,000 - $25,000
# 2        11566.80    $10,000 - $25,000
# 3        12954.32    $10,000 - $25,000
# 4        26758.40   $25,000 - $100,000
